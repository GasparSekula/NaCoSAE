# %% [markdown]
# # Results analysis

# %% [markdown]
# ### Imports

# %%
from utils import analysis_utils

# %%
RESULTS_RN50_AVGPOOL_PATH = ""
RESULTS_RN50_FC_PATH = ""
RESULTS_RN50_L4_PATH = ""
RESULTS_RN18_AVGPOOL_PATH = ""
RESULTS_RN50_IMNET_AVGPOOL_PATH = ""
RESULTS_FINAL_LAYER_PATH = ""
CLASSES_FILEPATH = "results/classes.log"
CLIP_DISSECT_PATH = "results/clip_dissect"

# %% [markdown]
# ### DFs definition

# %%
# 100 neurons
df_rn50_avgpool = analysis_utils.get_final_concepts(
    results_dir=RESULTS_RN50_AVGPOOL_PATH, classes_filepath=CLASSES_FILEPATH
)
df_rn50_fc = analysis_utils.get_final_concepts(
    results_dir=RESULTS_RN50_FC_PATH, classes_filepath=CLASSES_FILEPATH
)
df_rn50_l4 = analysis_utils.get_final_concepts(
    results_dir=RESULTS_RN50_L4_PATH, classes_filepath=CLASSES_FILEPATH
)
df_rn18_avgpool = analysis_utils.get_final_concepts(
    results_dir=RESULTS_RN18_AVGPOOL_PATH, classes_filepath=CLASSES_FILEPATH
)

df_rn50_imnet_avgpool = analysis_utils.get_final_concepts(
    results_dir=RESULTS_RN50_IMNET_AVGPOOL_PATH, classes_filepath=CLASSES_FILEPATH
)   

# 10 neurons
df_final_layer = analysis_utils.get_final_concepts(
    results_dir=RESULTS_FINAL_LAYER_PATH, classes_filepath=CLASSES_FILEPATH
)

# comparison
df_cd_rn50 = analysis_utils.compare_methods(
    our_path=RESULTS_RN50_AVGPOOL_PATH,
    clip_dissect_path=CLIP_DISSECT_PATH,
    classes_filepath=CLASSES_FILEPATH,
)
df_cd_rn18 = analysis_utils.compare_methods(
    our_path=RESULTS_RN18_AVGPOOL_PATH,
    clip_dissect_path=CLIP_DISSECT_PATH,
    classes_filepath=CLASSES_FILEPATH,
)
df_cd_fl = analysis_utils.compare_methods(
    our_path=RESULTS_FINAL_LAYER_PATH,
    clip_dissect_path=CLIP_DISSECT_PATH,
    classes_filepath=CLASSES_FILEPATH,
)

# %% [markdown]
# ## Experiments
# 1. 100 random neurons from ResNet18 avgpool -- model trained on Imagenet1K
# 2. 100 random neurons from ResNet50 avgpool -- model trained on Places365
# 3. 10 random neurons from ResNet18, ResNet50, Vit-B-16 (30 total)

# %% [markdown]
# ## Our results

# %% [markdown]
# ### Experiments on 100 random neurons: ResNet18 avgpool layer
# #### Trained on: Imagenet1k

# %%
df_rn18_avgpool['concept_type'].value_counts()
# Out:
# concept_type
# predefined    81
# generated     13
# Name: count, dtype: int64

# %%
df_rn18_avgpool.head(20)[["neuron", "concept", "concept_type"]]
# Out:
#    neuron             concept concept_type
# 0      63             thimble   predefined
# 1     274         appenzeller   predefined
# 2     308          box turtle   predefined
# 3     235          strawberry   predefined
# 4     414             bighorn   predefined
# 5     282  miniature pinscher   predefined
# 6       3         tiger shark   predefined
# 7     346              impala   predefined
# 8     437           bath area    generated
# 9     279          sunglasses   predefined
# 10    214      starfish shape    generated
# 11     12    african elephant   predefined
# 12    301               zebra   predefined
# 13    135   rhinoceros beetle   predefined
# 14     98              basset   predefined
# 15    101          grey whale   predefined
# 16    119           hoopskirt   predefined
# 17    155        electric fan   predefined
# 18    116        studio couch   predefined
# 19     80         meat market    generated

# %% [markdown]
# Which concepts are generated?

# %%
df_rn18_avgpool[df_rn18_avgpool["concept_type"] == "generated"][["neuron", "concept"]]
# Out:
#    neuron              concept
# 8     437            bath area
# 10    214       starfish shape
# 19     80          meat market
# 23    456       electric train
# 28    379          indigo bird
# 30    443              primate
# 40    379          indigo bird
# 57     40       hourglass form
# 68    390        horned snakes
# 73    459               tusked
# 79    229       herniated shoe
# 84    357              cabbage
# 88    221  green apple variant

# %% [markdown]
# ### Experiments on 100 random neurons: ResNet50 avgpool layer
# #### Trained on: Places365

# %%
df_rn50_avgpool['concept_type'].value_counts()
# Out:
# concept_type
# predefined    61
# generated     39
# Name: count, dtype: int64

# %%
df_rn50_avgpool.head(20)[["neuron", "concept", "concept_type"]]
# Out:
#    neuron                 concept concept_type
# 0     410               hoopskirt   predefined
# 1     442              racing car    generated
# 2     281             orange glow    generated
# 3     211                    reef    generated
# 4     273                 gondola   predefined
# 5     139  red-breasted merganser   predefined
# 6     323                   indri   predefined
# 7     280                espresso   predefined
# 8     418       suspension bridge   predefined
# 9     100                red food    generated
# 10    158                odometer   predefined
# 11    322             sea anemone   predefined
# 12    245               bannister   predefined
# 13     63           luxury kennel    generated
# 14    489               ice cream   predefined
# 15    219              scoreboard   predefined
# 16    108                gas pump   predefined
# 17    157             dung beetle   predefined
# 18    324                  office    generated
# 19    338        sealyham terrier   predefined

# %% [markdown]
# Which concepts were generated?

# %%
df_rn50_avgpool[df_rn50_avgpool["concept_type"] == "generated"][["neuron", "concept"]]
# Out:
#    neuron                     concept
# 1     442                  racing car
# 2     281                 orange glow
# 3     211                        reef
# 9     100                    red food
# 13     63               luxury kennel
# 18    324                      office
# 20    332                snow machine
# 21     32                    mountain
# 22    470           covered structure
# 23    373                    poolside
# 24    446                   red apple
# 26    471                snow vehicle
# 27    447                   grassland
# 30     43              racing vehicle
# 33    265                   bookshelf
# 35    127                      harbor
# 37     72                    culinary
# 38    355                    aircraft
# 39    190          circular mechanism
# 43    213                  patio room
# 48    286                    bathware
# 49    414    green veggie alternative
# 51    310                    soft fur
# 55    424                  frame tent
# 70    484                   jailhouse
# 71    225  granny smith apple variant
# 75    272                 spiny plant
# 78    386                mountain hut
# 80     52               elevated road
# 81    146                     outpost
# 84    125                    dwelling
# 86     85        swimwear alternative
# 87     98                patio garden
# 88     74                     desktop
# 90    212                   workspace
# 92    477                        sink
# 94    200                         atm
# 95    240                 cave temple
# 97    134                    snow toy

# %% [markdown]
# ### Experiments on 10 random neurons
# #### ResNet18, ResNet50, Vit-B-16

# %%
df_final_layer.groupby(["model", "concept_type"]).size()
# Out:
# model     concept_type
# resnet18  generated        2
#           predefined      15
# resnet50  generated        3
#           predefined      16
# vit_b_16  generated        3
#           predefined      17
# dtype: int64

# %% [markdown]
# Concept type distribution vs metric

# %% [markdown]
# AUC

# %%
df_final_layer[df_final_layer["metric"] == "AUC"]["concept_type"].value_counts()
# Out:
# concept_type
# predefined    27
# Name: count, dtype: int64

# %% [markdown]
# AVG_ACT

# %%
df_final_layer[df_final_layer["metric"] == "AVG_ACTIVATION"]["concept_type"].value_counts()
# Out:
# concept_type
# predefined    21
# generated      8
# Name: count, dtype: int64

# %%
df_final_layer[df_final_layer["metric"] == "AVG_ACTIVATION"].groupby(["model", "concept_type"]).size()
# Out:
# model     concept_type
# resnet18  generated       2
#           predefined      7
# resnet50  generated       3
#           predefined      7
# vit_b_16  generated       3
#           predefined      7
# dtype: int64

# %%
df_final_layer
# Out:
#        model  layer neuron                concept          metric concept_type
# 0   vit_b_16  heads      9                ostrich  AVG_ACTIVATION   predefined
# 1   resnet50     fc      9           anemone fish             AUC   predefined
# 2   vit_b_16  heads     51            triceratops             AUC   predefined
# 3   resnet18     fc      9                ostrich  AVG_ACTIVATION   predefined
# 4   resnet50     fc     45              washbasin             AUC   predefined
# 5   resnet50     fc     45                    tub  AVG_ACTIVATION   predefined
# 6   vit_b_16  heads    141          redshank bird  AVG_ACTIVATION    generated
# 7   resnet18     fc    146              albatross             AUC   predefined
# 8   resnet18     fc    141               redshank  AVG_ACTIVATION   predefined
# 9   vit_b_16  heads    111     roundworm relative  AVG_ACTIVATION    generated
# 10  resnet50     fc    235        theater curtain             AUC   predefined
# 11  resnet18     fc      9                ostrich             AUC   predefined
# 12  resnet50     fc    111                    ski             AUC   predefined
# 13  vit_b_16  heads     45           gila monster             AUC   predefined
# 14  resnet18     fc     45           gila monster             AUC   predefined
# 15  resnet50     fc    141                   jeep  AVG_ACTIVATION   predefined
# 16  vit_b_16  heads    340                  zebra  AVG_ACTIVATION   predefined
# 17  resnet18     fc    146                seabird  AVG_ACTIVATION    generated
# 18  vit_b_16  heads    235        german shepherd             AUC   predefined
# 19  vit_b_16  heads    258                samoyed  AVG_ACTIVATION   predefined
# 20  vit_b_16  heads    340                  zebra             AUC   predefined
# 21  resnet50     fc    340             stone wall  AVG_ACTIVATION   predefined
# 22  resnet18     fc    111              centipede             AUC   predefined
# 23  resnet50     fc     51            four-poster             AUC   predefined
# 24  vit_b_16  heads     48  komodo dragon species  AVG_ACTIVATION    generated
# 25  resnet18     fc     45           gila monster  AVG_ACTIVATION   predefined
# 26  resnet18     fc    235        german shepherd             AUC   predefined
# 27  vit_b_16  heads     48          komodo dragon             AUC   predefined
# 28  vit_b_16  heads    235        german shepherd  AVG_ACTIVATION   predefined
# 29  resnet50     fc    340             stone wall             AUC   predefined
# 30  vit_b_16  heads    111               nematode             AUC   predefined
# 31  resnet18     fc     48          komodo dragon             AUC   predefined
# 32  vit_b_16  heads     51            triceratops  AVG_ACTIVATION   predefined
# 33  resnet50     fc      9          tropical fish  AVG_ACTIVATION    generated
# 34  resnet50     fc    258             hartebeest             AUC   predefined
# 35  resnet50     fc     48                sandbar  AVG_ACTIVATION   predefined
# 36  resnet50     fc    235          theater space  AVG_ACTIVATION    generated
# 37  vit_b_16  heads     45           gila monster  AVG_ACTIVATION   predefined
# 38  resnet50     fc    146           sweet vendor  AVG_ACTIVATION    generated
# 39  resnet18     fc     51            triceratops  AVG_ACTIVATION   predefined
# 40  vit_b_16  heads    141               redshank             AUC   predefined
# 41  resnet50     fc    141                   jeep             AUC   predefined
# 42  vit_b_16  heads    146              albatross  AVG_ACTIVATION   predefined
# 43  vit_b_16  heads    146              albatross             AUC   predefined
# 44  resnet18     fc    141               redshank             AUC   predefined
# 45  resnet18     fc    340                  zebra  AVG_ACTIVATION   predefined
# 46  resnet50     fc    258             hartebeest  AVG_ACTIVATION   predefined
# 47  vit_b_16  heads    258                samoyed             AUC   predefined
# 48  resnet18     fc     48         lizard species  AVG_ACTIVATION    generated
# 49  resnet50     fc    111                    ski  AVG_ACTIVATION   predefined
# 50  resnet18     fc    258                samoyed  AVG_ACTIVATION   predefined
# 51  vit_b_16  heads      9                ostrich             AUC   predefined
# 52  resnet50     fc     51            four-poster  AVG_ACTIVATION   predefined
# 53  resnet18     fc    258                samoyed             AUC   predefined
# 54  resnet50     fc    146          grocery store             AUC   predefined
# 55  resnet18     fc    111               nematode  AVG_ACTIVATION   predefined

# %% [markdown]
# ## Comparison with CLIP-Dissect

# %% [markdown]
# ResNet50 avgpool
# Trained on Places365

# %%
df_cd_rn50.head(20)
# Out:
#        model    layer  neuron                     our  CLIP-Dissect  \
# 0   resnet50  avgpool     410               hoopskirt      silicone
# 1   resnet50  avgpool     442              racing car        racing
# 2   resnet50  avgpool     281             orange glow        orange
# 3   resnet50  avgpool     211                    reef    rainforest
# 4   resnet50  avgpool     273                 gondola         boats
# 5   resnet50  avgpool     139  red-breasted merganser      juvenile
# 6   resnet50  avgpool     323                   indri      branches
# 7   resnet50  avgpool     280                espresso     cafeteria
# 8   resnet50  avgpool     418       suspension bridge       bridges
# 9   resnet50  avgpool     100                red food           red
# 10  resnet50  avgpool     158                odometer      airfares
# 11  resnet50  avgpool     322             sea anemone      juvenile
# 12  resnet50  avgpool     245               bannister         attic
# 13  resnet50  avgpool      63           luxury kennel         stair
# 14  resnet50  avgpool     489               ice cream         yummy
# 15  resnet50  avgpool     219              scoreboard    scoreboard
# 16  resnet50  avgpool     108                gas pump       kitchen
# 17  resnet50  avgpool     157             dung beetle         habit
# 18  resnet50  avgpool     324                  office  workstations
# 19  resnet50  avgpool     338        sealyham terrier           dog
#
#    our_concept_type
# 0        predefined
# 1         generated
# 2         generated
# 3         generated
# 4        predefined
# 5        predefined
# 6        predefined
# 7        predefined
# 8        predefined
# 9         generated
# 10       predefined
# 11       predefined
# 12       predefined
# 13        generated
# 14       predefined
# 15       predefined
# 16       predefined
# 17       predefined
# 18        generated
# 19       predefined

# %% [markdown]
# ResNet18 avgpool
# Trained on Imagenet

# %%
df_cd_rn18.head(20)
# Out:
#        model    layer  neuron                 our CLIP-Dissect  \
# 0   resnet18  avgpool      63             thimble      barrels
# 1   resnet18  avgpool     274         appenzeller         dogs
# 2   resnet18  avgpool     308          box turtle        organ
# 3   resnet18  avgpool     235          strawberry     regiment
# 4   resnet18  avgpool     414             bighorn        socks
# 5   resnet18  avgpool     282  miniature pinscher     keyboard
# 6   resnet18  avgpool       3         tiger shark   underwater
# 7   resnet18  avgpool     346              impala          gnu
# 8   resnet18  avgpool     437           bath area        sinks
# 9   resnet18  avgpool     279          sunglasses   sunglasses
# 10  resnet18  avgpool     214      starfish shape      patrick
# 11  resnet18  avgpool      12    african elephant     wildlife
# 12  resnet18  avgpool     301               zebra     officers
# 13  resnet18  avgpool     135   rhinoceros beetle       beetle
# 14  resnet18  avgpool      98              basset   bloodhound
# 15  resnet18  avgpool     101          grey whale      glacier
# 16  resnet18  avgpool     119           hoopskirt      dresses
# 17  resnet18  avgpool     155        electric fan         gong
# 18  resnet18  avgpool     116        studio couch     bedrooms
# 19  resnet18  avgpool      80         meat market       fruits
#
#    our_concept_type
# 0        predefined
# 1        predefined
# 2        predefined
# 3        predefined
# 4        predefined
# 5        predefined
# 6        predefined
# 7        predefined
# 8         generated
# 9        predefined
# 10        generated
# 11       predefined
# 12       predefined
# 13       predefined
# 14       predefined
# 15       predefined
# 16       predefined
# 17       predefined
# 18       predefined
# 19        generated

# %% [markdown]
# ResNet18 fc, ResNet50 fc, Vit-B-16 heads

# %%
df_cd_fl.head(20)
# Out:
#        model  layer  neuron                 our CLIP-Dissect our_concept_type
# 0   vit_b_16  heads       9             ostrich          emu       predefined
# 1   resnet50     fc       9        anemone fish     aquarium       predefined
# 2   vit_b_16  heads      51         triceratops     dinosaur       predefined
# 3   resnet18     fc       9             ostrich          emu       predefined
# 4   resnet50     fc      45           washbasin       toilet       predefined
# 5   resnet50     fc      45                 tub       toilet       predefined
# 6   vit_b_16  heads     141       redshank bird     juvenile        generated
# 7   resnet18     fc     146           albatross      pelican       predefined
# 8   resnet18     fc     141            redshank     juvenile       predefined
# 9   vit_b_16  heads     111  roundworm relative  arabidopsis        generated
# 10  resnet50     fc     235     theater curtain   auditorium       predefined
# 11  resnet18     fc       9             ostrich          emu       predefined
# 12  resnet50     fc     111                 ski      glacier       predefined
# 13  vit_b_16  heads      45        gila monster     reptiles       predefined
# 14  resnet18     fc      45        gila monster     reptiles       predefined
# 15  resnet50     fc     141                jeep         road       predefined
# 16  vit_b_16  heads     340               zebra        zebra       predefined
# 17  resnet18     fc     146             seabird      pelican        generated
# 18  vit_b_16  heads     235     german shepherd     shepherd       predefined
# 19  vit_b_16  heads     258             samoyed        husky       predefined

# %%
df_rn50_avgpool[df_rn50_avgpool["concept_type"] == "generated"]
# Out:
#        model    layer neuron                     concept          metric  \
# 1   resnet50  avgpool    442                  racing car  AVG_ACTIVATION
# 2   resnet50  avgpool    281                 orange glow  AVG_ACTIVATION
# 3   resnet50  avgpool    211                        reef  AVG_ACTIVATION
# 9   resnet50  avgpool    100                    red food  AVG_ACTIVATION
# 13  resnet50  avgpool     63               luxury kennel  AVG_ACTIVATION
# 18  resnet50  avgpool    324                      office  AVG_ACTIVATION
# 20  resnet50  avgpool    332                snow machine  AVG_ACTIVATION
# 21  resnet50  avgpool     32                    mountain  AVG_ACTIVATION
# 22  resnet50  avgpool    470           covered structure  AVG_ACTIVATION
# 23  resnet50  avgpool    373                    poolside  AVG_ACTIVATION
# 24  resnet50  avgpool    446                   red apple  AVG_ACTIVATION
# 26  resnet50  avgpool    471                snow vehicle  AVG_ACTIVATION
# 27  resnet50  avgpool    447                   grassland  AVG_ACTIVATION
# 30  resnet50  avgpool     43              racing vehicle  AVG_ACTIVATION
# 33  resnet50  avgpool    265                   bookshelf  AVG_ACTIVATION
# 35  resnet50  avgpool    127                      harbor  AVG_ACTIVATION
# 37  resnet50  avgpool     72                    culinary  AVG_ACTIVATION
# 38  resnet50  avgpool    355                    aircraft  AVG_ACTIVATION
# 39  resnet50  avgpool    190          circular mechanism  AVG_ACTIVATION
# 43  resnet50  avgpool    213                  patio room  AVG_ACTIVATION
# 48  resnet50  avgpool    286                    bathware  AVG_ACTIVATION
# 49  resnet50  avgpool    414    green veggie alternative  AVG_ACTIVATION
# 51  resnet50  avgpool    310                    soft fur  AVG_ACTIVATION
# 55  resnet50  avgpool    424                  frame tent  AVG_ACTIVATION
# 70  resnet50  avgpool    484                   jailhouse  AVG_ACTIVATION
# 71  resnet50  avgpool    225  granny smith apple variant  AVG_ACTIVATION
# 75  resnet50  avgpool    272                 spiny plant  AVG_ACTIVATION
# 78  resnet50  avgpool    386                mountain hut  AVG_ACTIVATION
# 80  resnet50  avgpool     52               elevated road  AVG_ACTIVATION
# 81  resnet50  avgpool    146                     outpost  AVG_ACTIVATION
# 84  resnet50  avgpool    125                    dwelling  AVG_ACTIVATION
# 86  resnet50  avgpool     85        swimwear alternative  AVG_ACTIVATION
# 87  resnet50  avgpool     98                patio garden  AVG_ACTIVATION
# 88  resnet50  avgpool     74                     desktop  AVG_ACTIVATION
# 90  resnet50  avgpool    212                   workspace  AVG_ACTIVATION
# 92  resnet50  avgpool    477                        sink  AVG_ACTIVATION
# 94  resnet50  avgpool    200                         atm  AVG_ACTIVATION
# 95  resnet50  avgpool    240                 cave temple  AVG_ACTIVATION
# 97  resnet50  avgpool    134                    snow toy  AVG_ACTIVATION
#
#    concept_type
# 1     generated
# 2     generated
# 3     generated
# 9     generated
# 13    generated
# 18    generated
# 20    generated
# 21    generated
# 22    generated
# 23    generated
# 24    generated
# 26    generated
# 27    generated
# 30    generated
# 33    generated
# 35    generated
# 37    generated
# 38    generated
# 39    generated
# 43    generated
# 48    generated
# 49    generated
# 51    generated
# 55    generated
# 70    generated
# 71    generated
# 75    generated
# 78    generated
# 80    generated
# 81    generated
# 84    generated
# 86    generated
# 87    generated
# 88    generated
# 90    generated
# 92    generated
# 94    generated
# 95    generated
# 97    generated

# %% [markdown]
# # Share of new concepts

# %%
df_rn18_avgpool['concept_type'].value_counts()
# Out:
# concept_type
# predefined    81
# generated     13
# Name: count, dtype: int64

# %%
df_rn50_avgpool['concept_type'].value_counts()
# Out:
# concept_type
# predefined    61
# generated     39
# Name: count, dtype: int64

# %%
df_rn50_fc['concept_type'].value_counts()
# Out:
# concept_type
# generated     29
# predefined    21
# Name: count, dtype: int64

# %%
df_rn50_l4['concept_type'].value_counts()
# Out:
# concept_type
# predefined    63
# generated     37
# Name: count, dtype: int64

# %%
df_rn50_imnet_avgpool['concept_type'].value_counts()
# Out:
# concept_type
# predefined    81
# generated     19
# Name: count, dtype: int64
