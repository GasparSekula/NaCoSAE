# %% [markdown]
# # Results analysis

# %%
RESULTS_PATH = ""
CLASSES_FILEPATH = ""

# %%
from utils import analysis_utils

# %%
df = analysis_utils.get_final_concepts(results_dir=RESULTS_PATH, classes_filepath=CLASSES_FILEPATH)

# %%
df['concept_type'].value_counts()
# Out:
# concept_type
# predefined    81
# generated     13
# Name: count, dtype: int64
